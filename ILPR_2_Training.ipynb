# %% [markdown]
# <a href="https://colab.research.google.com/github/anmoltiwari05/Indian-License-plate-detection-with-YOLOv3-using-Transfer-Learning/blob/master/ILPR_2_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# After moving the dataset into the Training directory, we move on to tweak the YOLO pre-trained Caffenet Model. Make sure that your training images (License plate images) **are in the right place and do not to change any folders name**

# %%
# %cd "gdrive/My Drive/ILPR/TrainYourOwnYOLO/"
# !pip install -r requirements.txt
### Restart the runtime

# %%
# !pip install tensorflow-gpu==1.15.2

# %%
# %cd "gdrive/My Drive/ILPR/TrainYourOwnYOLO/2_Training/"
# Out:
# /content/gdrive/My Drive/ILPR/TrainYourOwnYOLO/2_Training

# %%
# !python Download_and_Convert_YOLO_weights.py

# %%
### Make sure that you have GPU selected as your Hardware Accelerator

# !python Train_YOLO.py
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0617 06:55:48.155247 140509633111936 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0617 06:55:48.155591 140509633111936 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0617 06:55:48.158978 140509633111936 module_wrapper.py:139] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...
